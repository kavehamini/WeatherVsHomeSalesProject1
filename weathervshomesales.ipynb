# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import datetime 
import json

# %%
file = 'Resources/kc_house_data.csv'
df=pd.read_csv(file)
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.sort_values('date')
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 16768  5561000190  20140502T000000   437500.0         3       2.25
# 9596    472000620  20140502T000000   790000.0         3       2.50
# 9587   1024069009  20140502T000000   675000.0         5       2.50
# 20602  7853361370  20140502T000000   555000.0         4       2.50
# 11577  5056500260  20140502T000000   440000.0         4       2.25
# 20559  3438501320  20140502T000000   295000.0         2       2.50
# 18690  1737320120  20140502T000000   470000.0         5       2.50
# 1041   7197300105  20140502T000000   550000.0         4       2.50
# 172    1999700045  20140502T000000   313000.0         3       1.50
# 7734   1962200037  20140502T000000   626000.0         3       2.25
# 5956   3328500250  20140502T000000   285000.0         4       2.50
# 7942   1088800850  20140502T000000   612500.0         4       2.50
# 11907  3221059036  20140502T000000   400000.0         4       2.50
# ...

# %%
weatherdata = pd.read_json('Resources/23075d28543cff25d003a483a55b9d88.json')

weatherdata.head()
# Out:
#    city_id       clouds          dt                         dt_iso  \
# 0  5799783   {'all': 1}  1356998400  2013-01-01 00:00:00 +0000 UTC
# 1  5799783   {'all': 1}  1357002000  2013-01-01 01:00:00 +0000 UTC
# 2  5799783  {'all': 20}  1357005600  2013-01-01 02:00:00 +0000 UTC
# 3  5799783   {'all': 1}  1357009200  2013-01-01 03:00:00 +0000 UTC
# 4  5799783  {'all': 75}  1357012800  2013-01-01 04:00:00 +0000 UTC
#
#                                                 main rain snow  \
# 0  {'temp': 275.62, 'temp_min': 271.48, 'temp_max...  NaN  NaN
# 1  {'temp': 275.61, 'temp_min': 273.71, 'temp_max...  NaN  NaN
# 2  {'temp': 274.23, 'temp_min': 270.37, 'temp_max...  NaN  NaN
# 3  {'temp': 273.95, 'temp_min': 270.37, 'temp_max...  NaN  NaN
# 4  {'temp': 273.55, 'temp_min': 269.82, 'temp_max...  NaN  NaN
#
#                                              weather                      wind
# 0  [{'id': 800, 'main': 'Clear', 'description': '...  {'speed': 1, 'deg': 350}
# ...

# %%
#new_df = pd.DataFrame(weatherdata["weather"])
#new_df.head()
#weatherdata["new_col22"] = [row.get("temp_min") for row in weatherdata["main"]]
# Out:
#    city_id       clouds          dt                         dt_iso  \
# 0  5799783   {'all': 1}  1356998400  2013-01-01 00:00:00 +0000 UTC
# 1  5799783   {'all': 1}  1357002000  2013-01-01 01:00:00 +0000 UTC
# 2  5799783  {'all': 20}  1357005600  2013-01-01 02:00:00 +0000 UTC
# 3  5799783   {'all': 1}  1357009200  2013-01-01 03:00:00 +0000 UTC
# 4  5799783  {'all': 75}  1357012800  2013-01-01 04:00:00 +0000 UTC
#
#                                                 main rain snow  \
# 0  {'temp': 275.62, 'temp_min': 271.48, 'temp_max...  NaN  NaN
# 1  {'temp': 275.61, 'temp_min': 273.71, 'temp_max...  NaN  NaN
# 2  {'temp': 274.23, 'temp_min': 270.37, 'temp_max...  NaN  NaN
# 3  {'temp': 273.95, 'temp_min': 270.37, 'temp_max...  NaN  NaN
# 4  {'temp': 273.55, 'temp_min': 269.82, 'temp_max...  NaN  NaN
#
#                                              weather  \
# 0  [{'id': 800, 'main': 'Clear', 'description': '...
# 1  [{'id': 800, 'main': 'Clear', 'description': '...
# ...

# %%
#weatherdata.drop(columns =["new_col", "new_col22"])
# Out:
#        city_id       clouds          dt                         dt_iso  \
# 0      5799783   {'all': 1}  1356998400  2013-01-01 00:00:00 +0000 UTC
# 1      5799783   {'all': 1}  1357002000  2013-01-01 01:00:00 +0000 UTC
# 2      5799783  {'all': 20}  1357005600  2013-01-01 02:00:00 +0000 UTC
# 3      5799783   {'all': 1}  1357009200  2013-01-01 03:00:00 +0000 UTC
# 4      5799783  {'all': 75}  1357012800  2013-01-01 04:00:00 +0000 UTC
# 5      5799783  {'all': 90}  1357016400  2013-01-01 05:00:00 +0000 UTC
# 6      5799783   {'all': 1}  1357020000  2013-01-01 06:00:00 +0000 UTC
# 7      5799783  {'all': 90}  1357023600  2013-01-01 07:00:00 +0000 UTC
# 8      5799783  {'all': 20}  1357027200  2013-01-01 08:00:00 +0000 UTC
# 9      5799783   {'all': 1}  1357030800  2013-01-01 09:00:00 +0000 UTC
# 10     5799783   {'all': 1}  1357034400  2013-01-01 10:00:00 +0000 UTC
# 11     5799783  {'all': 20}  1357038000  2013-01-01 11:00:00 +0000 UTC
# ...

# %%
#weatherdata.head()
# Out:
#    city_id       clouds          dt                         dt_iso  \
# 0  5799783   {'all': 1}  1356998400  2013-01-01 00:00:00 +0000 UTC
# 1  5799783   {'all': 1}  1357002000  2013-01-01 01:00:00 +0000 UTC
# 2  5799783  {'all': 20}  1357005600  2013-01-01 02:00:00 +0000 UTC
# 3  5799783   {'all': 1}  1357009200  2013-01-01 03:00:00 +0000 UTC
# 4  5799783  {'all': 75}  1357012800  2013-01-01 04:00:00 +0000 UTC
#
#                                                 main rain snow  \
# 0  {'temp': 275.62, 'temp_min': 271.48, 'temp_max...  NaN  NaN
# 1  {'temp': 275.61, 'temp_min': 273.71, 'temp_max...  NaN  NaN
# 2  {'temp': 274.23, 'temp_min': 270.37, 'temp_max...  NaN  NaN
# 3  {'temp': 273.95, 'temp_min': 270.37, 'temp_max...  NaN  NaN
# 4  {'temp': 273.55, 'temp_min': 269.82, 'temp_max...  NaN  NaN
#
#                                              weather  \
# 0  [{'id': 800, 'main': 'Clear', 'description': '...
# 1  [{'id': 800, 'main': 'Clear', 'description': '...
# ...

# %%
#new_df['weather']

# %%
#new_df['weather'][0]

# %%
#new_df['weather'][0][0]['main']
