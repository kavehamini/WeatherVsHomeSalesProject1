# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from config import api_key, client_id, client_secret
import requests
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-f6ed4c7c3951> in <module>
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 from config import api_key, client_id, cliend_secret
#       5 import requests
#
# ImportError: cannot import name 'client_id'

# %%
file = 'Resources/kc_house_data.csv'
df=pd.read_csv(file)
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.sort_values('date')
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 16768  5561000190  20140502T000000   437500.0         3       2.25
# 9596    472000620  20140502T000000   790000.0         3       2.50
# 9587   1024069009  20140502T000000   675000.0         5       2.50
# 20602  7853361370  20140502T000000   555000.0         4       2.50
# 11577  5056500260  20140502T000000   440000.0         4       2.25
# ...           ...              ...        ...       ...        ...
# 7898   1422700040  20150514T000000   183000.0         3       1.00
# 928    8730000270  20150514T000000   359000.0         2       2.75
# 5637   7923600250  20150515T000000   450000.0         5       2.00
# 13053  5101400871  20150524T000000   445500.0         2       1.75
# 16594  9106000005  20150527T000000  1310000.0         4       2.25
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 16768         1970     35100     2.0           0     0  ...      9
# ...

# %%
url='https://api.aerisapi.com/normals/seattle,wa?'
query_url = url+"&from="+2014/01/01+"&to="+2014/02/02+"&filter=daily&format=json&client_id="+cliend_id+"&client_secret="+client_secret

response = requests.get(query_url).json()
response
# Out:
# {'success': True,
#  'error': None,
#  'response': {'id': 'usw00024281',
#   'loc': {'long': -122.3, 'lat': 47.65},
#   'place': {'name': 'seattle urban site', 'state': 'wa', 'country': 'us'},
#   'periods': [{'type': 'daily',
#     'mon': 8,
#     'day': 22,
#     'timestamp': 1566432000,
#     'dateTimeISO': '2019-08-22T00:00:00+00:00',
#     'temp': {'maxF': 75.7,
#      'maxC': 24.28,
#      'minF': 56.8,
#      'minC': 13.78,
#      'avgF': 66.2,
#      'avgC': 19},
#     'prcp': {'ytdIN': 20.67, 'ytdMM': 525, 'mtdIN': 0.61, 'mtdMM': 15},
#     'snow': {'ytdIN': 1.8, 'ytdCM': 4.6, 'mtdIN': 0, 'mtdCM': 0},
#     'hdd': 1,
#     'cdd': 2}],
#   'profile': {'tz': 'America/Los_Angeles'},
#   'relativeTo': {'lat': 47.60621,
#    'long': -122.33207,
#    'bearing': 26,
#    'bearingENG': 'NNE',
#    'distanceKM': 5.43,
#    'distanceMI': 3.374}}}

# %%
url='http://history.openweathermap.org/data/2.5/history/city?'

startdate = df['date'].min()
enddate = df['date'].max()
query_url=url+"q=King County,US&appid="+api_key+"&type=hour"+"&start="+startdate+"&end="+enddate

response = requests.get(query_url).json()
response
# Out:
# {'cod': 401,
#  'message': 'Invalid API key. Please see http://openweathermap.org/faq#error401 for more info.'}

# %%
url = 'https://api2.realtor.ca/Listing.svc/PropertySearch_Post'
